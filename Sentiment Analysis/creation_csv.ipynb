# %% [markdown]
# # Creation of csv which will be used

# %% [markdown]
# After running 'sentimental.py' and 'scraper.py', execute this code.

# %%
# import some functions from another Jupyter
# %run 0_all_functions.ipynb
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/valentinaolaritei/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/valentinaolaritei/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/valentinaolaritei/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# read sentimental obtained from sentimental.py
path = './Data/sp500_news_and_sentimental.csv'
df2 = pd.read_csv(path)
df2.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 stock                   date  \
# 0             0           0   zts   5/22/2013 2:52:27 PM
# 1             1           1   zts   6/24/2013 4:28:40 PM
# 2             2           2   zts  6/25/2015 10:35:18 PM
# 3             3           3   zts  5/10/2016 12:57:59 AM
# 4             4           4   zts   2/27/2017 1:10:00 PM
#
#                                                title       source  \
# 0    Pfizer to spin off Zoetis stake to shareholders      Reuters
# 1  Pfizer says shareholders snap up remaining Zoe...      Reuters
# 2                  Valeant offers to buy Zoetis: WSJ      Reuters
# 3  Ackman's Pershing Square seeks to sell Zoetis ...      Reuters
# 4  Technical Reports on Generic Drugs Stocks -- Z...  PR Newswire
#
#                                          link_source  positivity_text  \
# 0  http://feeds.reuters.com/~r/reuters/businessNe...            0.000
# 1  http://feeds.reuters.com/~r/reuters/businessNe...            0.239
# ...

# %%
# drop useless columns
df2.drop(columns = ['Unnamed: 0', 'Unnamed: 0.1'], inplace=True)
df2.head()
# Out:
#   stock                   date  \
# 0   zts   5/22/2013 2:52:27 PM
# 1   zts   6/24/2013 4:28:40 PM
# 2   zts  6/25/2015 10:35:18 PM
# 3   zts  5/10/2016 12:57:59 AM
# 4   zts   2/27/2017 1:10:00 PM
#
#                                                title       source  \
# 0    Pfizer to spin off Zoetis stake to shareholders      Reuters
# 1  Pfizer says shareholders snap up remaining Zoe...      Reuters
# 2                  Valeant offers to buy Zoetis: WSJ      Reuters
# 3  Ackman's Pershing Square seeks to sell Zoetis ...      Reuters
# 4  Technical Reports on Generic Drugs Stocks -- Z...  PR Newswire
#
#                                          link_source  positivity_text  \
# 0  http://feeds.reuters.com/~r/reuters/businessNe...            0.000
# 1  http://feeds.reuters.com/~r/reuters/businessNe...            0.239
# 2  http://feeds.reuters.com/~r/reuters/businessNe...            0.000
# 3  http://feeds.reuters.com/~r/reuters/businessNe...            0.167
# ...

# %%
# rename column
df2.rename(columns={'stock':'ticker'}, inplace=True)
df2.head()
# Out:
#   ticker                   date  \
# 0    zts   5/22/2013 2:52:27 PM
# 1    zts   6/24/2013 4:28:40 PM
# 2    zts  6/25/2015 10:35:18 PM
# 3    zts  5/10/2016 12:57:59 AM
# 4    zts   2/27/2017 1:10:00 PM
#
#                                                title       source  \
# 0    Pfizer to spin off Zoetis stake to shareholders      Reuters
# 1  Pfizer says shareholders snap up remaining Zoe...      Reuters
# 2                  Valeant offers to buy Zoetis: WSJ      Reuters
# 3  Ackman's Pershing Square seeks to sell Zoetis ...      Reuters
# 4  Technical Reports on Generic Drugs Stocks -- Z...  PR Newswire
#
#                                          link_source  positivity_text  \
# 0  http://feeds.reuters.com/~r/reuters/businessNe...            0.000
# 1  http://feeds.reuters.com/~r/reuters/businessNe...            0.239
# 2  http://feeds.reuters.com/~r/reuters/businessNe...            0.000
# 3  http://feeds.reuters.com/~r/reuters/businessNe...            0.167
# ...

# %%
# call function for other Jupyter
df1 = get_sp500_indexes()
df1.head()
# Out:
#   ticker        stock            gisc_sectors
# 0    mmm           3M             Industrials
# 1    aos  A. O. Smith             Industrials
# 2    abt       Abbott             Health Care
# 3   abbv       AbbVie             Health Care
# 4    acn    Accenture  Information Technology

# %%
# verify position of brk.b ---> it will be changed into brk
df1[df1['ticker'] == 'brk.b']
# Out:
#    ticker               stock gisc_sectors
# 62  brk.b  Berkshire Hathaway   Financials

# %%
# change ticker name
df1.loc[62, 'ticker'] = 'brk'

# %%
# add necessary data to sentimental CSV
df_merged = pd.merge(df2, df1, on='ticker', how='left')
df_merged.head()
# Out:
#   ticker                   date  \
# 0    zts   5/22/2013 2:52:27 PM
# 1    zts   6/24/2013 4:28:40 PM
# 2    zts  6/25/2015 10:35:18 PM
# 3    zts  5/10/2016 12:57:59 AM
# 4    zts   2/27/2017 1:10:00 PM
#
#                                                title       source  \
# 0    Pfizer to spin off Zoetis stake to shareholders      Reuters
# 1  Pfizer says shareholders snap up remaining Zoe...      Reuters
# 2                  Valeant offers to buy Zoetis: WSJ      Reuters
# 3  Ackman's Pershing Square seeks to sell Zoetis ...      Reuters
# 4  Technical Reports on Generic Drugs Stocks -- Z...  PR Newswire
#
#                                          link_source  positivity_text  \
# 0  http://feeds.reuters.com/~r/reuters/businessNe...            0.000
# 1  http://feeds.reuters.com/~r/reuters/businessNe...            0.239
# 2  http://feeds.reuters.com/~r/reuters/businessNe...            0.000
# 3  http://feeds.reuters.com/~r/reuters/businessNe...            0.167
# ...

# %%
# output
df_merged.to_csv('sp500_news_and_sentimental.csv')
